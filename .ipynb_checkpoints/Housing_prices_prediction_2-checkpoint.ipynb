# %%
# %reset
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model, decomposition
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from pandas import read_csv
import pandas as pd
from matplotlib import style
import seaborn as sns
from sklearn.linear_model import LassoCV

#from sklearn.model_selection import cross_val_score
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
#plotting details
style.use('fivethirtyeight') #who were you expecting?
# %config InlineBackend.figure_format = 'png' #'png' goes faster
# %matplotlib inline

# %%
#def replace_object_with_cat_codes(df):
#given an input dataframe, replace all objects with cat-codes.
#note:building a linear model on top of these now 'numeric' features is 
#not a good idea
def replace_object_with_cat_codes(df):
    cols_obj = df.select_dtypes(['object']).columns
    for i_col in cols_obj:
        df[i_col] = df[i_col].astype('category')
    cat_cols = df.select_dtypes(['category']).columns
    df[cat_cols] = df[cat_cols].apply(lambda x: x.cat.codes)
    return df
#-----
from scipy.stats import skew
#def unskew_cols(df):
#unskew the columns
def unskew_cols(df):
    ind_contin = df.dtypes[df.dtypes !="object"].index
    cont_skew = df[ind_contin].apply(lambda l: skew(l.dropna()))
    cont_skew = cont_skew[cont_skew > .8]
    cont_skew = cont_skew.index
    df[cont_skew] = np.log1p(df[cont_skew])
    return df
#-----
from scipy.stats import f_oneway
#def unskew_cols(df):
#unskew the columns
def prune_category_data_by_anova(data_prune):
    obj_columns = data_prune.select_dtypes(['object']).columns
    l=len(obj_columns)
    i = 0
    list_bad = []
    for col in obj_columns:
        grps = pd.unique(data_prune[col])
        #print grps
        d_data = {grp:data_all['SalePrice'][data_prune[col] == grp] for grp in pd.unique(data_prune[col])}
        f_val, p_val = f_oneway(*d_data.values())  
        if p_val < 0.05:
            i = i +1
            #print("cols of value: %i" % i)        
        else:
            list_bad.append(col)
            data_prune.drop(col,axis=1,inplace=True)
    print("anova pruning reduced to %i columns from %i" % (i,l))
    return (data_prune,list_bad)

def add_missing_columns_for_model(df_complete,df_incomplete):
    for col in df_complete.columns:
        if col not in df_incomplete.columns:
            xadd = pd.DataFrame(np.zeros([df_incomplete.shape[0],1]), index=np.arange(0,df_incomplete.shape[0]), columns=[col])
            df_incomplete = pd.concat([df_incomplete, xadd], axis=1)
    return df_incomplete

# def results(pred,y_test):
# plot the predicted results against the actual results.
def big_errors(pred_dollars,act_dollars,thresh):
    difference = np.abs(pred_dollars-act_dollars)
    i_bad_pred = np.where(difference>thresh)
    #print(i_bad_pred)
    return i_bad_pred[0]

def results(pred,y_test):
    rmsle = np.sqrt(np.mean((np.log(pred+1) - np.log(y_test+1))**2))
    rms_error = np.sqrt(np.mean((pred - y_test)**2))
    rms_perc_error = np.sqrt(np.mean(((pred - y_test)/y_test)**2))*100
    plt.plot(y_test,pred,linestyle='None',marker='.',markersize=20)
    plt.xlabel('actual ($)')
    plt.ylabel('predicted ($)')
    plt.axis('equal')
    plt.show()
    thresh_outlier = 75000
    potential_outliers = big_errors(pred,y_test,thresh_outlier)
    print('Outliers further away than %i' % thresh_outlier)
    print potential_outliers
    print('RMSLE=%.4f RMSE=%.2f; the percent error is %.2f.' % (rmsle, rms_error,rms_perc_error))
    return rmsle
    
# def output_from_log_score(predict,df_all,fname): 
# given 1) results in Log score NOT $ (predict), and 2) the dataframe that has 'Id',
# spit out ['id','predict'] to fname (written as a csv)
def output_from_log_score(predict,df_all,fname):
    pred_val_dollars = np.expm1(predict)
    data_out=pd.DataFrame({"Id": pd.Series(df_all['Id'])})
    data_out['SalePrice']=pd.Series(pred_val_dollars)
    data_out.to_csv(fname,index=False)

# %%
data_all = read_csv('train.csv',header=0)
data_test = read_csv('test.csv',header=0)

# %% [markdown]
# Step 1: Random Forests Regressor
#
# Maybe no processing on the data and no feature engineering works okay with a powerful model. Here I try a quick-and-dirty RandomForestsRegressor. The only pre-processing I use is removal of skew.

# %%
def forest_pre_process(data_in):
    data_rf = data_in.copy()
    data_rf = unskew_cols(data_rf)
    data_rf = pd.get_dummies(data_rf)
    data_rf = data_rf.fillna(data_rf.median())
    return data_rf

from sklearn.ensemble import RandomForestRegressor
def forest_fit(X,Y):
    x_train, x_test, y_train, y_test = train_test_split(X,Y)
    rf_mod=RandomForestRegressor(n_estimators=500)
    rf_mod.fit(x_train, y_train)
    pred=rf_mod.predict(x_test)
    pred_dollar = np.expm1(pred)
    y_dollar = np.expm1(y_test)
    #fitrmsle.append(results(pred,y_test)) #for skewed data only
    results(pred_dollar,y_dollar)
    return rf_mod

data_train = data_all.copy()
Y = data_train['SalePrice']
Y = np.log1p(Y)
data_train.drop('SalePrice',axis=1,inplace=True)
data_train = forest_pre_process(data_train)
tree_model = forest_fit(data_train,Y)

data_tree_test = data_test.copy()
data_tree_test = forest_pre_process(data_tree_test)
data_tree_test = add_missing_columns_for_model(data_train,data_tree_test)
y_tree_predict=tree_model.predict(data_tree_test)
output_from_log_score(y_tree_predict,data_test,'jer_tree.csv')
# Out:
# Outliers further away than 75000
# [ 39  49  93 189 242 249 254 280 308 355]
# RMSLE=0.1506 RMSE=32525.16; the percent error is 18.84.

# %% [markdown]
# RandomForestsRegressor generates a pretty poor score based on Kaggle.
#
# A more interpretable place to start is a regression model of our data. Here we use Lasso regression, which tweaks linear regression by regularizing. That is, we do not just seek to minimize the sum of squares, we also penalize the magnitude of the (absolute value of) coefficients.
#
# In addition to allowing Lasso to do its on feature selection we prune based on univariate tests using Anova. One line can be commented in or out to generate separate predictions.

# %%
#-----
# def show_lasso_model_cols(model,n):
# graphical display of the best and worst predictors (predictors = 2*n)
#lasso specific: show the best n model columns.
def show_lasso_model_cols(model,cols,n):
    import pandas as pd
    gains=pd.Series(model.coef_,index=cols)
    gains.sort_values().plot()
    plt.show()
    print('lasso got rid of %i of %i variables.' % (sum(gains==0),len(gains)))
    num_best = n
    gains_best_pred=pd.concat([gains.sort_values().head(num_best),gains.sort_values().tail(num_best)])
    gains_best_pred.plot(kind='bar')
#-----
#here is our workflow for the training data:
def data_clean_lasso(df_in):
    df_lasso_all = df_in.copy()                  # make a copy of the original data
    df_lasso = df_lasso_all.loc[:,'MSSubClass':] # ignore the Id
    df_lasso = unskew_cols(df_lasso)             # unskew. we don't know how normal the data are.
    df_lasso,list_bad = prune_category_data_by_anova(df_lasso) # remove cols by anova.
    df_lasso = pd.get_dummies(df_lasso)          # convert categorical data to extra cols.
    df_lasso = df_lasso.fillna(df_lasso.median()) # fill in unknown data with the median.
    return (df_lasso,list_bad)                     # return the new data, and the list.

#-----
# here is our workflow for the test data. 
# it is slightly different because we reject cols based on the previous analysis.
def data_clean_lasso_test(df_in,df_model_lasso,list_bad):
    df_lasso_all = df_in.copy()
    df_lasso = df_lasso_all.loc[:,'MSSubClass':]
    df_lasso = unskew_cols(df_lasso)
    [df_lasso.drop(col,axis=1,inplace=True) for col in list_bad]
    df_lasso = pd.get_dummies(df_lasso)
    df_lasso = df_lasso.fillna(df_lasso.median())    
    df_lasso = add_missing_columns_for_model(df_model_lasso,df_lasso)
    return df_lasso

# def add_missing_columns_for_model(df_complete,df_incomplete):
# it's fair game to have missing columns in your test data.
# this just means that the test data doesn't have all of the categories
# you trained on.


X,list_bad = data_clean_lasso(data_all)
Y = X['SalePrice']
X.drop('SalePrice',axis=1,inplace=True)
for i in range(0,1):
    x_train, x_test, y_train, y_test = train_test_split(X, Y,test_size=.25,random_state=1)
    print x_test.shape
    lasso_mod=LassoCV(alphas=[1, 0.1, 0.001, 0.0005]).fit(x_train,y_train)
    pred = lasso_mod.predict(x_test)
    pred_dollars = np.expm1(pred)
    y_test_dollars = np.expm1(y_test)
    results(pred_dollars,y_test_dollars)

    #now generate a prediction
    X_TEST = data_clean_lasso_test(data_test,X,list_bad)

    TEST_COST = lasso_mod.predict(X_TEST)
    output_from_log_score(TEST_COST,data_test,'jerday2.csv')
    show_lasso_model_cols(lasso_mod,X_TEST.columns,15)
# Out:
# anova pruning reduced to 24 columns from 43
# (365, 211)
# Outliers further away than 75000
# [136 186 204 220]
# RMSLE=0.1144 RMSE=24280.41; the percent error is 12.30.
# lasso got rid of 116 of 211 variables.

# %% [markdown]
# The lasso coefficients suggest that neighbourhood has a pretty huge effect. Several of them (StoneBr, Drawfor,NoRidge,NridgHt,ClearCr) make up the lion's share of the positive coefficients.
#
# Tests with and without Anova pruning show that, despite Lasso's own regularization based on features, which prunes predictors to almost 1/3rd, Anova gets rid of another 10% total columns, and improves performance on the test data.
#
# Lasso occasionally generates extremely high negative predictors depending on the train/test split. RoofMatl_ClyTile and Exterior1st_asbShng are two examples that occur.
#
#
# How many samples have such extremely negative predictors?

# %%
# Bad predictors.
#we notice that clay tile has an extremely large negative coefficient on it. 
cly=np.where(data_all.RoofMatl=='ClyTile')
cly_test=np.where(data_test.RoofMatl=='ClayTile')
print('The number of samples in the training set with ClyTile is %i' % len(cly))
print('The number of samples in the test set with ClyTile is %i' % len(cly_test))

asb=np.where(data_all.Exterior1st=='asbShng')
asb_test=np.where(data_test.Exterior1st=='asbShng')
print('The number of samples in the training set with asb_shng is %i' % len(asb))
print('The number of samples in the test set with asb_shng is %i' % len(asb_test))
# Out:
# The number of samples in the training set with ClyTile is 1
# The number of samples in the test set with ClyTile is 1
# The number of samples in the training set with asb_shng is 1
# The number of samples in the test set with asb_shng is 1

# %% [markdown]
# So it is interesting to note despite being a strong predictor it will apply to little or even none of the data.

# %% [markdown]
# What if we drammatically remove data? Let's get rid of all of the columns except for 'Neighbourhood' and 'Exterior1st'.  We keep the numeric features in the model but remove all of the remaining categorical columns.

# %%
data_small=data_all.copy()
ind_numeric = data_all.dtypes[data_all.dtypes !="object"].index
ind_cat = data_all.dtypes[data_all.dtypes =="object"].index
print data_all.columns[data_all.dtypes=='object']
data_small=data_small[ind_numeric]
xadd = pd.DataFrame(pd.Series(data_all['Neighborhood']), index=np.arange(0,data_small.shape[0]), columns=['Neighbourhood'])
data_small = pd.concat([data_small, xadd], axis=1)
xadd = pd.DataFrame(pd.Series(data_all['Exterior1st']), index=np.arange(0,data_small.shape[0]), columns=['Exterior1st'])
data_small = pd.concat([data_small,xadd],axis=1)


Y = data_small['SalePrice']
Y = np.log1p(Y)
data_small = unskew_cols(data_small)
data_small,list_bad = prune_category_data_by_anova(data_small) # remove cols by anova.
data_small = pd.get_dummies(data_small)          # convert categorical data to extra cols.
data_small = data_small.fillna(data_small.median()) # fill in unknown data with the median.
data_small.drop('SalePrice',axis=1,inplace=True)
x_train,x_test,y_train,y_test = train_test_split(data_small,Y,random_state=1)
#print data_all.hist['BsmtCond']

lasso_mod_small=LassoCV(alphas=[1, 0.1, 0.001, 0.0005]).fit(x_train,y_train)
pred = lasso_mod_small.predict(x_test)
pred_dollars = np.expm1(pred)
y_test_dollars = np.expm1(y_test)
results(pred_dollars,y_test_dollars)
# Out:
# Index([u'MSZoning', u'Street', u'Alley', u'LotShape', u'LandContour',
#        u'Utilities', u'LotConfig', u'LandSlope', u'Neighborhood',
#        u'Condition1', u'Condition2', u'BldgType', u'HouseStyle', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual', u'BsmtCond',
#        u'BsmtExposure', u'BsmtFinType1', u'BsmtFinType2', u'Heating',
#        u'HeatingQC', u'CentralAir', u'Electrical', u'KitchenQual',
#        u'Functional', u'FireplaceQu', u'GarageType', u'GarageFinish',
#        u'GarageQual', u'GarageCond', u'PavedDrive', u'PoolQC', u'Fence',
#        u'MiscFeature', u'SaleType', u'SaleCondition'],
#       dtype='object')
# anova pruning reduced to 1 columns from 2
# Outliers further away than 75000
# [ 28 122 136 220]
# RMSLE=0.1316 RMSE=28735.53; the percent error is 14.87.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-203c7da38e6e> in <module>()
#      25 y_test_dollars = np.expm1(y_test)
#      26 results(pred_dollars,y_test_dollars)
# ---> 27 show_lasso_model_cols(lasso_mod_small,x_test,10)
#
# <ipython-input-126-c7333cf8b6d3> in show_lasso_model_cols(model, cols, n)
#       5 def show_lasso_model_cols(model,cols,n):
#       6     import pandas as pd
# ----> 7     gains=pd.Series(model.coef_,index=cols)
#       8     gains.sort_values().plot()
#       9     plt.show()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     241                                        raise_cast_failure=True)
#     242
# --> 243                 data = SingleBlockManager(data, index, fastpath=True)
#     244
#     245         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in __init__(self, block, axis, do_integrity_check, fastpath)
#    4066         if not isinstance(block, Block):
#    4067             block = make_block(block, placement=slice(0, len(axis)), ndim=1,
# -> 4068                                fastpath=True)
#    4069
#    4070         self.blocks = [block]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2683                      placement=placement, dtype=dtype)
#    2684
# -> 2685     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2686
#    2687 # TODO: flexible with index=None and/or items=None
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in __init__(self, values, placement, ndim, fastpath)
#     107             raise ValueError('Wrong number of items passed %d, placement '
#     108                              'implies %d' % (len(self.values),
# --> 109                                              len(self.mgr_locs)))
#     110
#     111     @property
#
# ValueError: Wrong number of items passed 52, placement implies 365
